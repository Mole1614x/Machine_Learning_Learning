# %% [markdown]
# # Multiple Linear Regression

# %% [raw]
# When there are multiple input features.
#
# House Price = Area + Bedrooms + Location + Age

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
data = {
    "Area":[1000,1200,1500,1800,2000],
    "Bedrooms": [2,2,3,3,4],
    "Age": [10,8,5,4,2],
    "Price": [50,60,75,90,110]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#    Area  Bedrooms  Age  Price
# 0  1000         2   10     50
# 1  1200         2    8     60
# 2  1500         3    5     75
# 3  1800         3    4     90
# 4  2000         4    2    110

# %%
x = df[["Area","Bedrooms","Age"]]
y = df[["Price"]]

model = LinearRegression()
model.fit(x,y)

prediction = model.predict([[1600,3,5]])
print("Predicted Price:", prediction[0])
# Out:
# Predicted Price: [82.72727273]
# /usr/local/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
